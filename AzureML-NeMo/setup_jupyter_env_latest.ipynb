# %%
pip install --upgrade pip==20.2.4
# Out:
# Collecting pip==20.2.4
#   Downloading pip-20.2.4-py2.py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 988 kB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.1.1
#     Uninstalling pip-20.1.1:
#       Successfully uninstalled pip-20.1.1
# Successfully installed pip-20.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip uninstall -y enum34
# Out:
# Found existing installation: enum34 1.1.10
# Uninstalling enum34-1.1.10:
#   Successfully uninstalled enum34-1.1.10

# %%
# !pip install -U torch==1.6 torchvision pytorch-lightning==1.0.3
# Out:
# Collecting torch==1.6
#   Downloading torch-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (748.8 MB)
#      |████████████████████████████████| 748.8 MB 4.1 kB/s  eta 0:00:011  |█▎                              | 30.2 MB 910 kB/s eta 0:13:10     |████████████████████████▋       | 575.5 MB 111.3 MB/s eta 0:00:02
# Collecting torchvision
#   Downloading torchvision-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 24.4 MB/s eta 0:00:01
# Collecting pytorch-lightning==1.0.3
#   Downloading pytorch_lightning-1.0.3-py3-none-any.whl (533 kB)
#      |████████████████████████████████| 533 kB 81.4 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from torch==1.6) (1.18.5)
# Requirement already satisfied, skipping upgrade: future in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from torch==1.6) (0.18.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from torchvision) (6.2.1)
# Collecting fsspec>=0.8.0
#   Downloading fsspec-0.8.4-py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 8.6 MB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: tqdm>=4.41.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning==1.0.3) (4.50.1)
# Requirement already satisfied, skipping upgrade: tensorboard>=2.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning==1.0.3) (2.3.0)
# Requirement already satisfied, skipping upgrade: PyYAML>=5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning==1.0.3) (5.3.1)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (50.3.0.post20201006)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (2.24.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.24.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (1.32.0)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (1.7.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (3.13.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (0.35.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (0.16.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (0.4.1)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (1.15.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (1.22.1)
# Requirement already satisfied, skipping upgrade: absl-py>=0.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (0.10.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.0.3) (3.3.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (1.25.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (2020.6.20)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (1.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (4.1.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (4.6)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (0.2.8)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (2.0.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (0.4.8)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.0.3) (3.3.0)
# Installing collected packages: torch, torchvision, fsspec, pytorch-lightning
#   Attempting uninstall: torch
#     Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.5.0
#     Uninstalling torchvision-0.5.0:
#       Successfully uninstalled torchvision-0.5.0
# Successfully installed fsspec-0.8.4 pytorch-lightning-1.0.3 torch-1.6.0 torchvision-0.7.0

# %%
# !pip install -U tensorflow==2.2.0 tensorflow-gpu==2.2.0 TensorBoard==2.2.0
# Out:
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2 MB)
#      |█████████████████████████████▏  | 470.7 MB 107.3 MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 516.2 MB 10 kB/s
# Collecting tensorflow-gpu==2.2.0
#   Downloading tensorflow_gpu-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2 MB)
#      |████████████████████████████▎   | 456.1 MB 73.0 MB/s eta 0:00:014
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 516.2 MB 4.6 kB/s s eta 0:00:01
# Collecting TensorBoard==2.2.0
#   Downloading tensorboard-2.2.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 72.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.32.0)
# Requirement already satisfied, skipping upgrade: scipy==1.4.1; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.12.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (0.35.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (3.3.0)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      |████████████████████████████████| 454 kB 80.6 MB/s eta 0:00:01
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (0.10.0)
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (3.13.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (2.10.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (1.22.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (3.3.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (0.16.1)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (1.7.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (2.24.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (0.4.1)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from TensorBoard==2.2.0) (50.3.0.post20201006)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->TensorBoard==2.2.0) (4.6)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->TensorBoard==2.2.0) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->TensorBoard==2.2.0) (4.1.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from markdown>=2.6.8->TensorBoard==2.2.0) (2.0.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->TensorBoard==2.2.0) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->TensorBoard==2.2.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->TensorBoard==2.2.0) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3,>=2.21.0->TensorBoard==2.2.0) (1.25.10)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->TensorBoard==2.2.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->TensorBoard==2.2.0) (0.4.8)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->TensorBoard==2.2.0) (3.3.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->TensorBoard==2.2.0) (3.1.0)
# Installing collected packages: TensorBoard, tensorflow-estimator, gast, astunparse, tensorflow, tensorflow-gpu
#   Attempting uninstall: TensorBoard
#     Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.1.0
#     Uninstalling tensorflow-estimator-2.1.0:
#       Successfully uninstalled tensorflow-estimator-2.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.2.2
#     Uninstalling gast-0.2.2:
#       Successfully uninstalled gast-0.2.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.1.0
#     Uninstalling tensorflow-2.1.0:
#       Successfully uninstalled tensorflow-2.1.0
#   Attempting uninstall: tensorflow-gpu
#     Found existing installation: tensorflow-gpu 2.1.0
#     Uninstalling tensorflow-gpu-2.1.0:
#       Successfully uninstalled tensorflow-gpu-2.1.0
# Successfully installed TensorBoard-2.2.0 astunparse-1.6.3 gast-0.3.3 tensorflow-2.2.0 tensorflow-estimator-2.2.0 tensorflow-gpu-2.2.0

# %%
# !pip install Cython
# Out:
# Requirement already satisfied: Cython in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (0.29.21)

# %%
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@4e4597a85d80c77603102603e35fb033ba852c64#egg=nemo_toolkit[all]
# Out:
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision 4e4597a85d80c77603102603e35fb033ba852c64) to /tmp/pip-install-m42801cs/nemo-toolkit
# Requirement already satisfied: numpy>=1.18.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (1.18.5)
# Collecting onnx>=1.7.0
#   Downloading onnx-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 898 kB/s eta 0:00:01
# Requirement already satisfied: pytorch-lightning>=1.0.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: python-dateutil in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (2.8.1)
# Requirement already satisfied: torch in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (1.6.0)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: wrapt in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (1.12.1)
# Requirement already satisfied: ruamel.yaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (0.16.12)
# Requirement already satisfied: scikit-learn in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (0.22.2.post1)
# Collecting omegaconf>=2.0.2
#   Downloading omegaconf-2.0.3-py3-none-any.whl (36 kB)
# Collecting hydra-core>=1.0.3
#   Downloading hydra_core-1.0.3-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 16.4 MB/s eta 0:00:01
# Collecting transformers>=3.1.0
#   Downloading transformers-3.4.0-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 17.1 MB/s eta 0:00:01
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.0 MB/s  eta 0:00:01
# Collecting isort[requirements]<5
#   Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 715 kB/s  eta 0:00:01
# Collecting parameterized
#   Downloading parameterized-0.7.4-py2.py3-none-any.whl (25 kB)
# Collecting pytest
#   Downloading pytest-6.1.1-py3-none-any.whl (272 kB)
#      |████████████████████████████████| 272 kB 19.5 MB/s eta 0:00:01
# Collecting pytest-runner
#   Using cached pytest_runner-5.2-py2.py3-none-any.whl (6.8 kB)
# Collecting sphinx
#   Downloading Sphinx-3.2.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 17.4 MB/s eta 0:00:01
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-1.0.0-py3-none-any.whl (14 kB)
# Collecting wandb
#   Downloading wandb-0.10.8-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 28.9 MB/s eta 0:00:01
# Collecting braceexpand
#   Downloading braceexpand-0.1.6-py2.py3-none-any.whl (5.4 kB)
# Collecting editdistance
#   Downloading editdistance-0.5.3-cp36-cp36m-manylinux1_x86_64.whl (178 kB)
#      |████████████████████████████████| 178 kB 23.8 MB/s eta 0:00:01
# Collecting frozendict
#   Downloading frozendict-1.2.tar.gz (2.6 kB)
# Collecting inflect
#   Downloading inflect-4.1.0-py3-none-any.whl (31 kB)
# Collecting kaldi-io
#   Downloading kaldi_io-0.9.4-py3-none-any.whl (14 kB)
# Collecting librosa
#   Downloading librosa-0.8.0.tar.gz (183 kB)
#      |████████████████████████████████| 183 kB 34.7 MB/s eta 0:00:01
# Collecting marshmallow
#   Downloading marshmallow-3.8.0-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.4 MB/s  eta 0:00:01
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (20.4)
# Collecting num2words
#   Downloading num2words-0.5.10-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 8.5 MB/s eta 0:00:01
# Collecting soundfile
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting torch-stft
#   Downloading torch_stft-0.1.4-py3-none-any.whl (6.2 kB)
# Collecting unidecode
#   Downloading Unidecode-1.1.1-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 30.9 MB/s eta 0:00:01
# Collecting webdataset
#   Downloading webdataset-0.1.40-py3-none-any.whl (32 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.1.3.tar.gz (8.9 kB)
# Requirement already satisfied: scipy in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: pandas in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (0.25.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 12 kB/s s eta 0:00:01
# Requirement already satisfied: pillow in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (6.2.1)
# Requirement already satisfied: torchvision in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: boto3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (1.15.14)
# Requirement already satisfied: h5py in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (2.10.0)
# Collecting matplotlib>=3.3.2
#   Downloading matplotlib-3.3.2-cp36-cp36m-manylinux1_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 37 kB/s s eta 0:00:01
# Requirement already satisfied: sentencepiece in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (0.1.91)
# Collecting torchtext
#   Downloading torchtext-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 81.2 MB/s eta 0:00:01
# Collecting youtokentome
#   Downloading youtokentome-1.0.6-cp36-cp36m-manylinux2010_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 81.9 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.41.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nemo_toolkit[all]) (4.50.1)
# Collecting rapidfuzz
#   Downloading rapidfuzz-0.12.4-cp36-cp36m-manylinux2010_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 83.5 MB/s eta 0:00:01
# Collecting gdown
#   Downloading gdown-3.12.2.tar.gz (8.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting megatron-lm==1.1.5
#   Downloading megatron_lm-1.1.5-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 65.2 MB/s eta 0:00:01
# Collecting pypinyin
#   Downloading pypinyin-0.39.1-py2.py3-none-any.whl (780 kB)
#      |████████████████████████████████| 780 kB 79.7 MB/s eta 0:00:01
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pystoi
#   Downloading pystoi-0.3.3.tar.gz (7.0 kB)
# Collecting pesq
#   Downloading pesq-0.0.1.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 7.6 MB/s  eta 0:00:01
# Requirement already satisfied: six in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnx>=1.7.0->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.7.4.3)
# Requirement already satisfied: protobuf in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.13.0)
# Requirement already satisfied: fsspec>=0.8.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: PyYAML>=5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning>=1.0.3->nemo_toolkit[all]) (5.3.1)
# Requirement already satisfied: future>=0.17.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.18.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytorch-lightning>=1.0.3->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: joblib>=0.11 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from scikit-learn->nemo_toolkit[all]) (0.14.1)
# Requirement already satisfied: dataclasses; python_version == "3.6" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from omegaconf>=2.0.2->nemo_toolkit[all]) (0.7)
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      |████████████████████████████████| 112 kB 79.5 MB/s eta 0:00:01
# Collecting importlib-resources; python_version < "3.9"
#   Downloading importlib_resources-3.0.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: filelock in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from transformers>=3.1.0->nemo_toolkit[all]) (3.0.12)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
#      |████████████████████████████████| 883 kB 78.9 MB/s eta 0:00:01
# Requirement already satisfied: requests in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from transformers>=3.1.0->nemo_toolkit[all]) (2.24.0)
# Collecting tokenizers==0.9.2
#   Downloading tokenizers-0.9.2-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 22.7 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from transformers>=3.1.0->nemo_toolkit[all]) (2020.10.11)
# Requirement already satisfied: toml>=0.9.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.1)
# Requirement already satisfied: click>=6.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from black==19.10b0->nemo_toolkit[all]) (7.1.2)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typed-ast>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: attrs>=18.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from black==19.10b0->nemo_toolkit[all]) (20.2.0)
# Requirement already satisfied: pathspec<1,>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from black==19.10b0->nemo_toolkit[all]) (0.8.0)
# Collecting pipreqs; extra == "requirements"
#   Downloading pipreqs-0.4.10-py2.py3-none-any.whl (25 kB)
# Collecting pip-api; extra == "requirements"
#   Downloading pip_api-0.0.14-py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 88.3 MB/s eta 0:00:01
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytest->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pytest->nemo_toolkit[all]) (0.13.1)
# Collecting py>=1.8.2
#   Downloading py-1.9.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 7.6 MB/s  eta 0:00:01
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.7 MB/s  eta 0:00:01
# Requirement already satisfied: Pygments>=2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from sphinx->nemo_toolkit[all]) (2.7.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Collecting babel>=1.3
#   Downloading Babel-2.8.0-py2.py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 70.1 MB/s eta 0:00:01
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.2 MB/s  eta 0:00:01
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 7.8 MB/s  eta 0:00:01
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 4.8 MB/s  eta 0:00:01
# Requirement already satisfied: setuptools in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from sphinx->nemo_toolkit[all]) (50.3.0.post20201006)
# Collecting docutils>=0.12
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 80.3 MB/s eta 0:00:01
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 75.3 MB/s eta 0:00:01
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Jinja2>=2.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from sphinx->nemo_toolkit[all]) (2.11.2)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting oset>=0.1.3
#   Downloading oset-0.1.3.tar.gz (7.3 kB)
# Collecting pybtex-docutils>=0.2.0
#   Downloading pybtex_docutils-0.2.2-py2.py3-none-any.whl (4.6 kB)
# Collecting pybtex>=0.20
#   Downloading pybtex-0.23.0-py2.py3-none-any.whl (279 kB)
#      |████████████████████████████████| 279 kB 75.9 MB/s eta 0:00:01
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.1-py3-none-any.whl (22 kB)
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
# Requirement already satisfied: GitPython>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from wandb->nemo_toolkit[all]) (3.1.9)
# Requirement already satisfied: psutil>=5.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from wandb->nemo_toolkit[all]) (5.7.2)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting sentry-sdk>=0.4.0
#   Downloading sentry_sdk-0.19.1-py2.py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 84.5 MB/s eta 0:00:01
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 6.0 MB/s  eta 0:00:01
# Collecting watchdog>=0.8.3
#   Downloading watchdog-0.10.3.tar.gz (94 kB)
#      |████████████████████████████████| 94 kB 2.0 MB/s  eta 0:00:01
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 78.9 MB/s eta 0:00:01
# Requirement already satisfied: decorator>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from librosa->nemo_toolkit[all]) (4.4.2)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      |████████████████████████████████| 323 kB 77.7 MB/s eta 0:00:01
# Collecting numba>=0.43.0
#   Downloading numba-0.51.2-cp36-cp36m-manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 71.7 MB/s eta 0:00:01:00:01
# Collecting pooch>=1.0
#   Downloading pooch-1.2.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.7 MB/s  eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging->nemo_toolkit[all]) (2.4.7)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: cffi>=1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from soundfile->nemo_toolkit[all]) (1.14.3)
# Requirement already satisfied: msgpack in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from webdataset->nemo_toolkit[all]) (1.0.0)
# Collecting simplejson
#   Downloading simplejson-3.17.2-cp36-cp36m-manylinux2010_x86_64.whl (127 kB)
#      |████████████████████████████████| 127 kB 82.7 MB/s eta 0:00:01
# Collecting objectio
#   Downloading objectio-0.2.29-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pytz>=2017.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pandas->nemo_toolkit[all]) (2020.1)
# Collecting nltk>=3.2.4
#   Downloading nltk-3.5.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 77.7 MB/s eta 0:00:01
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      |████████████████████████████████| 180 kB 71.9 MB/s eta 0:00:01
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3->nemo_toolkit[all]) (0.10.0)
# Requirement already satisfied: botocore<1.19.0,>=1.18.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3->nemo_toolkit[all]) (1.18.14)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from boto3->nemo_toolkit[all]) (0.3.3)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (0.10.0)
# Requirement already satisfied: certifi>=2020.06.20 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (2020.6.20)
# Requirement already satisfied: kiwisolver>=1.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (1.2.0)
# Collecting pybind11
#   Downloading pybind11-2.6.0-py2.py3-none-any.whl (187 kB)
#      |████████████████████████████████| 187 kB 78.3 MB/s eta 0:00:01
# Requirement already satisfied: grpcio>=1.24.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (1.32.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (1.7.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.16.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.35.1)
# Requirement already satisfied: markdown>=2.6.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (3.3.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (1.22.1)
# Requirement already satisfied: absl-py>=0.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.10.0)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-resources; python_version < "3.9"->hydra-core>=1.0.3->nemo_toolkit[all]) (3.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests->transformers>=3.1.0->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests->transformers>=3.1.0->nemo_toolkit[all]) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests->transformers>=3.1.0->nemo_toolkit[all]) (3.0.4)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pip in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pip-api; extra == "requirements"->isort[requirements]<5->nemo_toolkit[all]) (20.2.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from Jinja2>=2.3->sphinx->nemo_toolkit[all]) (1.1.1)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from GitPython>=1.0.0->wandb->nemo_toolkit[all]) (4.0.5)
# Collecting pathtools>=0.1.1
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting llvmlite<0.35,>=0.34.0.dev0
#   Downloading llvmlite-0.34.0-cp36-cp36m-manylinux2010_x86_64.whl (24.6 MB)
#      |████████████████████████████████| 24.6 MB 72.0 MB/s eta 0:00:01
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.20)
# Collecting typer
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (4.6)
# Requirement already satisfied: smmap<4,>=3.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->nemo_toolkit[all]) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.3->nemo_toolkit[all]) (0.4.8)
# Building wheels for collected packages: nemo-toolkit, wget, frozendict, librosa, kaldi-python-io, gdown, pystoi, pesq, antlr4-python3-runtime, sacremoses, oset, promise, subprocess32, watchdog, audioread, resampy, docopt, nltk, distance, pathtools
#   Building wheel for nemo-toolkit (setup.py) ... done
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-1.0.0b1-py3-none-any.whl size=477046 sha256=6a7d14ee868ded6d9311968566f5b9434864be63abf7e110fee9bc4fc37c7535
#   Stored in directory: /home/azureuser/.cache/pip/wheels/44/67/17/e980bf0195d0a54efac4671a2493bef4e2702f10dc2513a18f
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9681 sha256=40f5c5d0ba2260d4c136b66e5e5760f444f0790ffbfbfb6e1385368f3678227c
#   Stored in directory: /home/azureuser/.cache/pip/wheels/90/1d/93/c863ee832230df5cfc25ca497b3e88e0ee3ea9e44adc46ac62
#   Building wheel for frozendict (setup.py) ... done
#   Created wheel for frozendict: filename=frozendict-1.2-py3-none-any.whl size=3148 sha256=39057cbc5a2eb7f10b48d9266e5ba785780f928b5973a6663512bc3d66c52642
#   Stored in directory: /home/azureuser/.cache/pip/wheels/c9/13/a1/b4f2255117a7dccdd6219408dce1d87446716b1bf77451cb97
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201376 sha256=50323b9bb6d64575054a1420efdb487af17187858568bf8da23e9b7b7b0c9f6e
#   Stored in directory: /home/azureuser/.cache/pip/wheels/32/2c/ce/86e49d4769aceba728421c24c0d726054bf4ca01175ff42bdd
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.1.3-py3-none-any.whl size=9094 sha256=629c7991002f3b4409b98124ae75b215755dc80209da37b2ba42f6574331b127
#   Stored in directory: /home/azureuser/.cache/pip/wheels/e7/1f/64/b38b424576754f421eb8da61c8882922ef57716f0d9d8b166b
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.12.2-py3-none-any.whl size=9681 sha256=008c205afcb0bfbeb50d21a01f9ad9a4b2e820a3ff6cbb45d6da8283e4d66795
#   Stored in directory: /home/azureuser/.cache/pip/wheels/33/15/6e/df5f8336275e96e19599034a76f9cfd81c6ae15d2bf16c11ca
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7782 sha256=ab3014f01108297b130afec8222084991008bc442fea54ca7657a1cec57e6eb6
#   Stored in directory: /home/azureuser/.cache/pip/wheels/47/80/53/bef5a8298048bc5d90f4460f3db05f6b53b1dff4cfa90349bb
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.1-cp36-cp36m-linux_x86_64.whl size=176838 sha256=fd20de19cb466d47202bf6c27af17950b082250280663fd5021b5e5521ee35c1
#   Stored in directory: /home/azureuser/.cache/pip/wheels/fb/f1/bb/14e674c17a92836d017bf6c1362e85cb09ce88d975050651da
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141229 sha256=571f50f925820affe4fa7cd5795c6407f2666e4f1dc97d56face00bf263a0acc
#   Stored in directory: /home/azureuser/.cache/pip/wheels/a8/04/35/9449686f1c26ff16f6224dc942e108329f3782185802ec6b93
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893259 sha256=64421e6e6855cf58f60d3c17e4070a9dca323ec2f627938ea4196bf2089f5176
#   Stored in directory: /home/azureuser/.cache/pip/wheels/49/25/98/cdea9c79b2d9a22ccc59540b1784b67f06b633378e97f58da2
#   Building wheel for oset (setup.py) ... done
#   Created wheel for oset: filename=oset-0.1.3-py3-none-any.whl size=9660 sha256=17a984683c5d1b9ef75da1cc5b8cbd715ce3cc8f5f3cf5ac9ceb47dcbb86b3ce
#   Stored in directory: /home/azureuser/.cache/pip/wheels/2a/7b/21/3720be257172cfef6e0703dc57888cf387c4e753524e990dfb
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=72193ae55ac2d069c0aee49aa572944f198ff7464e58c5a9eee674e6f03aa0e9
#   Stored in directory: /home/azureuser/.cache/pip/wheels/59/9a/1d/3f1afbbb5122d0410547bf9eb50955f4a7a98e53a6d8b99bd1
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6487 sha256=461f1b353717c0f3cfb450cedbc7ae73fe8051af0ccea42b8193c16d93726992
#   Stored in directory: /home/azureuser/.cache/pip/wheels/44/3a/ab/102386d84fe551b6cedb628ed1e74c5f5be76af8b909aeda09
#   Building wheel for watchdog (setup.py) ... done
#   Created wheel for watchdog: filename=watchdog-0.10.3-py3-none-any.whl size=73868 sha256=0d03ce4f0300e9b3ba134abdb3d8e11f0c75752e95a01d2157a1caacb681605f
#   Stored in directory: /home/azureuser/.cache/pip/wheels/a1/d5/fc/fddf5870c0fb0b755abdf41f4889ef54742ee21fff693aae22
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23140 sha256=c1251da8924c2216394e76895647b3c2d075aefc543c188fe50b158d124297ad
#   Stored in directory: /home/azureuser/.cache/pip/wheels/de/14/0a/863e4ed680b3204444cf486733e609d7ff7abe8fceafab67dc
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320718 sha256=f5c84b34e33591871bc5bc891bb6a2be66ddf6485428ca70e309a5bae1d5ea84
#   Stored in directory: /home/azureuser/.cache/pip/wheels/cf/d4/04/49d8824a42bd9f9b11d502727965b9997f0d41d2b22ae4f645
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=ccaba33704a7355cd28ddbdaa6f06e22a6d9beb75819559fdd9016ff9548cff3
#   Stored in directory: /home/azureuser/.cache/pip/wheels/3f/2a/fa/4d7a888e69774d5e6e855d190a8a51b357d77cc05eb1c097c9
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434672 sha256=2250d9ad575efa06a25cb0d6637a92e3e85218b516b733877c2ac471c90e6eac
#   Stored in directory: /home/azureuser/.cache/pip/wheels/de/5e/42/64abaeca668161c3e2cecc24f864a8fc421e3d07a104fc8a51
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16261 sha256=0a2a502ba637ae846296ba8a97dc2998de373658e5c57a285e77cc20b1f36a6f
#   Stored in directory: /home/azureuser/.cache/pip/wheels/73/fe/4f/755e0e7c4458783fb3d772007ffd70f6e8c4a6ab7ff40c7767
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8785 sha256=d5956743eb53dbd4ba7108c7ffe36b385facee546e0de33e60af2bd017ea2c4a
#   Stored in directory: /home/azureuser/.cache/pip/wheels/42/ea/90/e37d463fb3b03848bf715080595de62545266f53dd546b2497
# Successfully built nemo-toolkit wget frozendict librosa kaldi-python-io gdown pystoi pesq antlr4-python3-runtime sacremoses oset promise subprocess32 watchdog audioread resampy docopt nltk distance pathtools
# Installing collected packages: onnx, wget, omegaconf, antlr4-python3-runtime, importlib-resources, hydra-core, sacremoses, tokenizers, transformers, appdirs, black, yarg, docopt, pipreqs, pip-api, isort, parameterized, iniconfig, py, pytest, pytest-runner, sphinxcontrib-qthelp, babel, sphinxcontrib-devhelp, imagesize, sphinxcontrib-serializinghtml, sphinxcontrib-htmlhelp, docutils, sphinxcontrib-applehelp, alabaster, sphinxcontrib-jsmath, sphinx, oset, latexcodec, pybtex, pybtex-docutils, sphinxcontrib-bibtex, docker-pycreds, configparser, promise, shortuuid, sentry-sdk, subprocess32, pathtools, watchdog, wandb, braceexpand, editdistance, frozendict, inflect, kaldi-io, audioread, llvmlite, numba, resampy, soundfile, pooch, librosa, marshmallow, num2words, sox, torch-stft, unidecode, simplejson, typer, objectio, webdataset, kaldi-python-io, nltk, distance, g2p-en, matplotlib, torchtext, youtokentome, rapidfuzz, gdown, pybind11, megatron-lm, pypinyin, attrdict, pystoi, pesq, nemo-toolkit
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.6.0
#     Uninstalling onnx-1.6.0:
#       Successfully uninstalled onnx-1.6.0
#   Attempting uninstall: antlr4-python3-runtime
#     Found existing installation: antlr4-python3-runtime 4.7.2
#     Uninstalling antlr4-python3-runtime-4.7.2:
#       Successfully uninstalled antlr4-python3-runtime-4.7.2
#   Attempting uninstall: isort
#     Found existing installation: isort 5.6.4
#     Uninstalling isort-5.6.4:
#       Successfully uninstalled isort-5.6.4
#   Attempting uninstall: configparser
#     Found existing installation: configparser 3.7.4
#     Uninstalling configparser-3.7.4:
#       Successfully uninstalled configparser-3.7.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.1
#     Uninstalling matplotlib-3.2.1:
#       Successfully uninstalled matplotlib-3.2.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# azureml-train-automl-runtime 1.16.0 requires onnx<=1.6.0,>=1.5.0, but you'll have onnx 1.7.0 which is incompatible.
# azureml-defaults 1.16.0 requires configparser==3.7.4, but you'll have configparser 5.0.1 which is incompatible.
# azureml-datadrift 1.16.0 requires matplotlib<=3.2.1,>=3.0.2, but you'll have matplotlib 3.3.2 which is incompatible.
# azureml-automl-runtime 1.16.0 requires onnx<=1.6.0,>=1.5.0, but you'll have onnx 1.7.0 which is incompatible.
# azure-cli 2.13.0 requires antlr4-python3-runtime~=4.7.2, but you'll have antlr4-python3-runtime 4.8 which is incompatible.
# azure-cli 2.13.0 requires azure-graphrbac~=0.60.0, but you'll have azure-graphrbac 0.61.1 which is incompatible.
# azure-cli 2.13.0 requires azure-mgmt-containerregistry==3.0.0rc15, but you'll have azure-mgmt-containerregistry 2.8.0 which is incompatible.
# azure-cli 2.13.0 requires azure-mgmt-keyvault==7.0.0b3, but you'll have azure-mgmt-keyvault 2.2.0 which is incompatible.
# azure-cli 2.13.0 requires cryptography<3.0.0,>=2.3.1, but you'll have cryptography 3.1.1 which is incompatible.
# azure-cli 2.13.0 requires pytz==2019.1, but you'll have pytz 2020.1 which is incompatible.
# azure-cli 2.13.0 requires websocket-client~=0.56.0, but you'll have websocket-client 0.57.0 which is incompatible.
# Successfully installed alabaster-0.7.12 antlr4-python3-runtime-4.8 appdirs-1.4.4 attrdict-2.0.1 audioread-2.1.9 babel-2.8.0 black-19.10b0 braceexpand-0.1.6 configparser-5.0.1 distance-0.1.3 docker-pycreds-0.4.0 docopt-0.6.2 docutils-0.16 editdistance-0.5.3 frozendict-1.2 g2p-en-2.1.0 gdown-3.12.2 hydra-core-1.0.3 imagesize-1.2.0 importlib-resources-3.0.0 inflect-4.1.0 iniconfig-1.1.1 isort-4.3.21 kaldi-io-0.9.4 kaldi-python-io-1.1.3 latexcodec-2.0.1 librosa-0.8.0 llvmlite-0.34.0 marshmallow-3.8.0 matplotlib-3.3.2 megatron-lm-1.1.5 nemo-toolkit-1.0.0b1 nltk-3.5 num2words-0.5.10 numba-0.51.2 objectio-0.2.29 omegaconf-2.0.3 onnx-1.7.0 oset-0.1.3 parameterized-0.7.4 pathtools-0.1.2 pesq-0.0.1 pip-api-0.0.14 pipreqs-0.4.10 pooch-1.2.0 promise-2.3 py-1.9.0 pybind11-2.6.0 pybtex-0.23.0 pybtex-docutils-0.2.2 pypinyin-0.39.1 pystoi-0.3.3 pytest-6.1.1 pytest-runner-5.2 rapidfuzz-0.12.4 resampy-0.2.2 sacremoses-0.0.43 sentry-sdk-0.19.1 shortuuid-1.0.1 simplejson-3.17.2 soundfile-0.10.3.post1 sox-1.4.1 sphinx-3.2.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-bibtex-1.0.0 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-1.0.3 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.4 subprocess32-3.5.4 tokenizers-0.9.2 torch-stft-0.1.4 torchtext-0.7.0 transformers-3.4.0 typer-0.3.2 unidecode-1.1.1 wandb-0.10.8 watchdog-0.10.3 webdataset-0.1.40 wget-3.2 yarg-0.1.9 youtokentome-1.0.6

# %%
# If you're not using Colab, you might need to upgrade jupyter notebook to avoid the following error:
# 'ImportError: IProgress not found. Please update jupyter and ipywidgets.'

! pip install ipywidgets
! jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (7.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets) (5.0.7)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets) (7.16.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.3)
# Requirement already satisfied: ipython-genutils in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.7.1)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (50.3.0.post20201006)
# Requirement already satisfied: backcall in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.5)
# Requirement already satisfied: jedi>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.17.2)
# Requirement already satisfied: tornado>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: jupyter-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.7)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.1.4)
# Requirement already satisfied: six in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.17.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (2.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (20.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (19.0.2)
# Requirement already satisfied: Send2Trash in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.1)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: nbconvert in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.0.7)
# Requirement already satisfied: jinja2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.2)
# Requirement already satisfied: prometheus-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.3.0)
# Requirement already satisfied: cffi>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.3)
# Requirement already satisfied: testpath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: bleach in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: jupyterlab-pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.4)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: nest-asyncio in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.1)
# Requirement already satisfied: async-generator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# Config option `kernel_spec_manager_class` not recognized by `EnableNBExtensionApp`.
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
from nemo.collections import nlp as nemo_nlp
from nemo.utils.exp_manager import exp_manager

import os
import wget 
import torch
import pytorch_lightning as pl
from omegaconf import OmegaConf
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# [NeMo W 2020-10-22 20:14:02 experimental:28] Module <class 'nemo.collections.nlp.modules.common.huggingface.auto.AutoModelEncoder'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2020-10-22 20:14:02 experimental:28] Module <class 'nemo.collections.nlp.modules.common.megatron.megatron_bert.MegatronBertEncoder'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# WARNING: APEX is not installed, multi_tensor_applier will not be available.
# WARNING: APEX is not installed, using torch.nn.LayerNorm instead of apex.normalization.FusedLayerNorm!

# %%
print("done!")
# Out:
# done!
